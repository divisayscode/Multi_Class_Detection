# %%
import numpy as np  # linear algebra
import pandas as pd 
import os

# %%
from zipfile import ZipFile

# Manually retype the correct path, do not copy-paste
zip_path = r'D:\multiset.zip'  # Use raw string for Windows path

# Open the zip file and extract its contents
with ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall()

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D,Flatten,Dense,MaxPooling2D,Dropout
from sklearn.metrics import accuracy_score

# %%
import ipywidgets as widgets
import io
from PIL import Image
import tqdm
from sklearn.model_selection import train_test_split
import cv2
from sklearn.utils import shuffle
import tensorflow as tf

# %%
import os
import cv2
import numpy as np

X_train = []
Y_train = []
image_size = 150
labels = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']

# Set the correct path to the dataset
dataset_path = 'D:/multiset'

# Load Training Data
for i in labels:
    folderPath = os.path.join(dataset_path, 'Training', i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath, j))
        img = cv2.resize(img, (image_size, image_size))
        X_train.append(img)
        Y_train.append(i)

# Load Testing Data
for i in labels:
    folderPath = os.path.join(dataset_path, 'Testing', i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath, j))
        img = cv2.resize(img, (image_size, image_size))
        X_train.append(img)
        Y_train.append(i)

# Convert to numpy arrays
X_train = np.array(X_train)
Y_train = np.array(Y_train)

print("Data loading complete!")
print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of Y_train: {Y_train.shape}")
# Out:
# Data loading complete!
# Shape of X_train: (3264, 150, 150, 3)
# Shape of Y_train: (3264,)

# %%
X_train,Y_train = shuffle(X_train,Y_train,random_state=101)
X_train.shape
# Out:
# (3264, 150, 150, 3)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,Y_train,test_size=0.1,random_state=101)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train=y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test=y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.3))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Dropout(0.3))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.3))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.3))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(4, activation='softmax'))  # 4 classes
# Out:
# C:\Users\TOSHIBA\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 146, 146, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 73, 73, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 73, 73, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 71, 71, 64)     │        36,928 │
# ...

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer='Adam', 
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint('best_model.h5.keras', 
                              monitor='val_accuracy', 
                              save_best_only=True, 
                              mode='max', 
                              verbose=1)

# %%
history = model.fit(X_train, y_train, 
                    validation_data=(X_test, y_test), 
                    epochs=10, 
                    batch_size=32, 
                    callbacks=[checkpoint])
# Out:
# Epoch 1/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2755 - loss: 3.1855
# Epoch 1: val_accuracy improved from -inf to 0.26606, saving model to best_model.h5.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 368s 4s/step - accuracy: 0.2757 - loss: 3.1707 - val_accuracy: 0.2661 - val_loss: 1.3624
# Epoch 2/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3847 - loss: 1.2999
# Epoch 2: val_accuracy improved from 0.26606 to 0.49847, saving model to best_model.h5.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 395s 4s/step - accuracy: 0.3853 - loss: 1.2992 - val_accuracy: 0.4985 - val_loss: 1.1262
# Epoch 3/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5397 - loss: 1.0569
# Epoch 3: val_accuracy improved from 0.49847 to 0.58104, saving model to best_model.h5.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 353s 4s/step - accuracy: 0.5397 - loss: 1.0566 - val_accuracy: 0.5810 - val_loss: 0.9445
# Epoch 4/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6096 - loss: 0.8951
# ...

# %%
history_2 = model.fit(X_train, y_train, 
                      validation_data=(X_test, y_test), 
                      epochs=10, 
                      batch_size=32, 
                      callbacks=[checkpoint])
# Out:
# Epoch 1/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8529 - loss: 0.4062
# Epoch 1: val_accuracy did not improve from 0.77370
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 354s 4s/step - accuracy: 0.8530 - loss: 0.4059 - val_accuracy: 0.7462 - val_loss: 0.5999
# Epoch 2/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8914 - loss: 0.2691
# Epoch 2: val_accuracy improved from 0.77370 to 0.80734, saving model to best_model.h5.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 355s 4s/step - accuracy: 0.8913 - loss: 0.2694 - val_accuracy: 0.8073 - val_loss: 0.4806
# Epoch 3/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9048 - loss: 0.2739
# Epoch 3: val_accuracy improved from 0.80734 to 0.84098, saving model to best_model.h5.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 380s 4s/step - accuracy: 0.9047 - loss: 0.2739 - val_accuracy: 0.8410 - val_loss: 0.4188
# Epoch 4/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9064 - loss: 0.2519
# ...

# %%
y_pred = model.predict(X_test)  # Get model predictions
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert probabilities to class indices
y_true_classes = np.argmax(y_test, axis=1)  # True class
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 681ms/step

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_true_classes, y_pred_classes)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 90.83%

# %%
from sklearn.metrics import classification_report

report = classification_report(y_true_classes, y_pred_classes, target_names=labels)
print(report)
# Out:
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.83      0.92      0.87        93
# meningioma_tumor       0.92      0.85      0.89        95
#         no_tumor       1.00      0.88      0.94        52
#  pituitary_tumor       0.94      0.97      0.95        87
#
#         accuracy                           0.91       327
#        macro avg       0.92      0.91      0.91       327
#     weighted avg       0.91      0.91      0.91       327

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# Assuming history.history contains data for the first 20 epochs
# and history_2.history contains data for the additional 5 epochs

# Training accuracy and validation accuracy for both runs
acc = history.history['accuracy'] + history_2.history['accuracy']  # Combine accuracies
val_acc = history.history['val_accuracy'] + history_2.history['val_accuracy']  # Combine validation accuracies

# Combine epochs from both runs
epochs = range(len(acc))

# Plotting the results
fig = plt.figure(figsize=(14,7))
plt.plot(epochs, acc, 'r', label="Training Accuracy")
plt.plot(epochs, val_acc, 'b', label="Validation Accuracy")
plt.legend(loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy Over Epochs')
plt.show()

# %%
 #Training accuracy and validation accuracy for both runs
loss = history.history['loss'] + history_2.history['loss']  # Combine accuracies
val_loss = history.history['val_loss'] + history_2.history['val_loss']  # Combine validation accuracies

# Combine epochs from both runs
epochs = range(len(loss))

# Plotting the results
fig = plt.figure(figsize=(14,7))
plt.plot(epochs, acc, 'r', label="Training loss")
plt.plot(epochs, val_acc, 'b', label="Validation loss")
plt.legend(loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.title('Training and Validation loss Over Epochs')
plt.show()

# %%
img = cv2.imread('Testing/no_tumor/image(1).jpg')
img = cv2.resize(img,(150,150))
img_array = np.array(img)
img_array.shape
# Out:
# (150, 150, 3)

# %%
img_array = img_array.reshape(1,150,150,3)
img_array.shape
# Out:
# (1, 150, 150, 3)

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img('Testing/no_tumor/image(101).jpg')
plt.imshow(img,interpolation='nearest')
plt.show()

# %%
a=model.predict(img_array)
indices = a.argmax()
indices
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 2
